# %% [markdown]
# ### Importación de datos

# %%
# %pip install pandas
import pandas as pd
# Out:
# Requirement already satisfied: pandas in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\jimoc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %%
import csv
from urllib.request import urlopen

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
response = urlopen(url)
data = csv.DictReader(response.read().decode('utf-8').splitlines())

for row in data:
    print(row)
# Out:
# {'Producto': 'Asistente virtual', 'Categoría del Producto': 'Electrónicos', 'Precio': '164300.0', 'Costo de envío': '6900.0', 'Fecha de Compra': '16/01/2021', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Mesa de comedor', 'Categoría del Producto': 'Muebles', 'Precio': '192300.0', 'Costo de envío': '8400.0', 'Fecha de Compra': '18/05/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '209600.0', 'Costo de envío': '15900.0', 'Fecha de Compra': '15/03/2021', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Cartagena', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '10.39972', 'lon': '-75.51444'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '757500.0', 'Costo de envío': '41000.0', 'Fecha de Compra': '03/05/2022', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Cali', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '335200.0', 'Costo de envío': '20200.0', 'Fecha de Compra': '07/11/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Bloques de construcción', 'Categoría del Producto': 'Juguetes', 'Precio': '24200.0', 'Costo de envío': '0.0', 'Fecha de Compra': '03/12/2020', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Muñeca bebé', 'Categoría del Producto': 'Juguetes', 'Precio': '44200.0', 'Costo de envío': '0.0', 'Fecha de Compra': '07/08/2021', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Lavavajillas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1189700.0', 'Costo de envío': '63700.0', 'Fecha de Compra': '18/06/2021', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Santa Marta', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '11.24079', 'lon': '-74.19904'}
# {'Producto': 'Lavadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1518200.0', 'Costo de envío': '79000.0', 'Fecha de Compra': '08/01/2022', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Carrito de control remoto', 'Categoría del Producto': 'Juguetes', 'Precio': '75200.0', 'Costo de envío': '5100.0', 'Fecha de Compra': '24/02/2020', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Refrigerador', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '2431300.0', 'Costo de envío': '127600.0', 'Fecha de Compra': '03/04/2020', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Lavavajillas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1417100.0', 'Costo de envío': '75700.0', 'Fecha de Compra': '05/07/2021', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Cartagena', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '10.39972', 'lon': '-75.51444'}
# {'Producto': 'Auriculares', 'Categoría del Producto': 'Electrónicos', 'Precio': '91800.0', 'Costo de envío': '5300.0', 'Fecha de Compra': '20/02/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Olla de presión', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '66700.0', 'Costo de envío': '1700.0', 'Fecha de Compra': '10/09/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Pereira', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.81333', 'lon': '-75.69611'}
# {'Producto': 'Bicicleta', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '613300.0', 'Costo de envío': '30800.0', 'Fecha de Compra': '04/09/2020', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Ciencia de datos con Python', 'Categoría del Producto': 'Libros', 'Precio': '56900.0', 'Costo de envío': '1200.0', 'Fecha de Compra': '16/12/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Balón de voleibol', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '58900.0', 'Costo de envío': '1300.0', 'Fecha de Compra': '03/05/2022', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Medellín', 'Calificación': '2', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Ajedrez de madera', 'Categoría del Producto': 'Juguetes', 'Precio': '29600.0', 'Costo de envío': '1800.0', 'Fecha de Compra': '22/07/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Santa Marta', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '11.24079', 'lon': '-74.19904'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '1891700.0', 'Costo de envío': '107900.0', 'Fecha de Compra': '09/01/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '138900.0', 'Costo de envío': '9800.0', 'Fecha de Compra': '10/01/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '435700.0', 'Costo de envío': '23400.0', 'Fecha de Compra': '11/03/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '50800.0', 'Costo de envío': '3100.0', 'Fecha de Compra': '11/07/2022', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Bicicleta', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '514500.0', 'Costo de envío': '27600.0', 'Fecha de Compra': '21/04/2022', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Kit de bancas', 'Categoría del Producto': 'Muebles', 'Precio': '293500.0', 'Costo de envío': '13800.0', 'Fecha de Compra': '06/03/2023', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Dashboards con Power BI', 'Categoría del Producto': 'Libros', 'Precio': '33500.0', 'Costo de envío': '0.0', 'Fecha de Compra': '14/02/2023', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cubertería', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '47900.0', 'Costo de envío': '3300.0', 'Fecha de Compra': '20/03/2021', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Set de ollas', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '139300.0', 'Costo de envío': '8100.0', 'Fecha de Compra': '06/03/2023', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Batería', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '583900.0', 'Costo de envío': '29300.0', 'Fecha de Compra': '14/09/2020', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cuerda para saltar', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '18400.0', 'Costo de envío': '1200.0', 'Fecha de Compra': '18/07/2020', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Barranquilla', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '10.96854', 'lon': '-74.78132'}
# {'Producto': 'Carrito de control remoto', 'Categoría del Producto': 'Juguetes', 'Precio': '79100.0', 'Costo de envío': '2400.0', 'Fecha de Compra': '15/12/2021', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Estufa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '564200.0', 'Costo de envío': '28200.0', 'Fecha de Compra': '08/09/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '153900.0', 'Costo de envío': '6400.0', 'Fecha de Compra': '15/08/2021', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Medellín', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cama box', 'Categoría del Producto': 'Muebles', 'Precio': '331400.0', 'Costo de envío': '17900.0', 'Fecha de Compra': '04/02/2020', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Medellín', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '55600.0', 'Costo de envío': '7700.0', 'Fecha de Compra': '26/04/2020', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Bloques de construcción', 'Categoría del Producto': 'Juguetes', 'Precio': '24700.0', 'Costo de envío': '1700.0', 'Fecha de Compra': '13/05/2021', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '62300.0', 'Costo de envío': '1500.0', 'Fecha de Compra': '22/05/2022', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Medellín', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Impresora', 'Categoría del Producto': 'Electrónicos', 'Precio': '300200.0', 'Costo de envío': '16200.0', 'Fecha de Compra': '16/08/2021', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Mesa de noche', 'Categoría del Producto': 'Muebles', 'Precio': '305400.0', 'Costo de envío': '16700.0', 'Fecha de Compra': '31/07/2021', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Dashboards con Power BI', 'Categoría del Producto': 'Libros', 'Precio': '30500.0', 'Costo de envío': '7500.0', 'Fecha de Compra': '17/08/2020', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cama box', 'Categoría del Producto': 'Muebles', 'Precio': '327200.0', 'Costo de envío': '15600.0', 'Fecha de Compra': '21/09/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Villavicencio', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.142', 'lon': '-73.62664'}
# {'Producto': 'Auriculares', 'Categoría del Producto': 'Electrónicos', 'Precio': '68300.0', 'Costo de envío': '1800.0', 'Fecha de Compra': '16/09/2022', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Armario', 'Categoría del Producto': 'Muebles', 'Precio': '513400.0', 'Costo de envío': '25500.0', 'Fecha de Compra': '02/08/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Dinosaurio Rex', 'Categoría del Producto': 'Juguetes', 'Precio': '13900.0', 'Costo de envío': '3100.0', 'Fecha de Compra': '27/04/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '362000.0', 'Costo de envío': '17500.0', 'Fecha de Compra': '19/02/2021', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '240300.0', 'Costo de envío': '11000.0', 'Fecha de Compra': '26/03/2022', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '12', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Bicicleta', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '428300.0', 'Costo de envío': '21000.0', 'Fecha de Compra': '17/12/2021', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Guitarra eléctrica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '679000.0', 'Costo de envío': '34300.0', 'Fecha de Compra': '24/02/2023', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Inírida', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '3.8653', 'lon': '-67.9239'}
# {'Producto': 'Set de ollas', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '100900.0', 'Costo de envío': '5600.0', 'Fecha de Compra': '19/07/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Secadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '739700.0', 'Costo de envío': '39900.0', 'Fecha de Compra': '05/05/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Sofá reclinable', 'Categoría del Producto': 'Muebles', 'Precio': '630000.0', 'Costo de envío': '31700.0', 'Fecha de Compra': '26/12/2022', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Cúcuta', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '7.89391', 'lon': '-72.50782'}
# {'Producto': 'Tablet ABXY', 'Categoría del Producto': 'Electrónicos', 'Precio': '1130300.0', 'Costo de envío': '58400.0', 'Fecha de Compra': '08/03/2023', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Kit de bancas', 'Categoría del Producto': 'Muebles', 'Precio': '318900.0', 'Costo de envío': '17200.0', 'Fecha de Compra': '19/12/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Impresora', 'Categoría del Producto': 'Electrónicos', 'Precio': '297000.0', 'Costo de envío': '16200.0', 'Fecha de Compra': '06/08/2022', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Batería', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '402200.0', 'Costo de envío': '21800.0', 'Fecha de Compra': '30/12/2020', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Cubo mágico 8x8', 'Categoría del Producto': 'Juguetes', 'Precio': '17100.0', 'Costo de envío': '0.0', 'Fecha de Compra': '03/09/2021', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Set de vasos', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '38700.0', 'Costo de envío': '2500.0', 'Fecha de Compra': '16/04/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Tablet ABXY', 'Categoría del Producto': 'Electrónicos', 'Precio': '605800.0', 'Costo de envío': '33500.0', 'Fecha de Compra': '14/02/2023', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Cúcuta', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '7.89391', 'lon': '-72.50782'}
# {'Producto': 'Lavavajillas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1122700.0', 'Costo de envío': '60000.0', 'Fecha de Compra': '28/02/2020', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Auriculares', 'Categoría del Producto': 'Electrónicos', 'Precio': '125900.0', 'Costo de envío': '7100.0', 'Fecha de Compra': '10/12/2021', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Dinosaurio Rex', 'Categoría del Producto': 'Juguetes', 'Precio': '18300.0', 'Costo de envío': '1400.0', 'Fecha de Compra': '01/07/2021', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '6', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cuerda para saltar', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '12800.0', 'Costo de envío': '0.0', 'Fecha de Compra': '25/09/2021', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Manizales', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '5.06889', 'lon': '-75.51738'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '423500.0', 'Costo de envío': '20700.0', 'Fecha de Compra': '23/05/2022', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Impresora', 'Categoría del Producto': 'Electrónicos', 'Precio': '315200.0', 'Costo de envío': '15000.0', 'Fecha de Compra': '01/09/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Modelado predictivo', 'Categoría del Producto': 'Libros', 'Precio': '74100.0', 'Costo de envío': '2100.0', 'Fecha de Compra': '24/08/2020', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de débito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Mesa de noche', 'Categoría del Producto': 'Muebles', 'Precio': '293800.0', 'Costo de envío': '16000.0', 'Fecha de Compra': '17/08/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '2525400.0', 'Costo de envío': '135000.0', 'Fecha de Compra': '03/03/2023', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Secadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1200300.0', 'Costo de envío': '64100.0', 'Fecha de Compra': '02/01/2022', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Modelado predictivo', 'Categoría del Producto': 'Libros', 'Precio': '53000.0', 'Costo de envío': '1000.0', 'Fecha de Compra': '31/03/2023', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Kit de bancas', 'Categoría del Producto': 'Muebles', 'Precio': '250100.0', 'Costo de envío': '14600.0', 'Fecha de Compra': '09/09/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Neiva', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '7', 'lat': '2.9273', 'lon': '-75.28189'}
# {'Producto': 'Estufa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '680900.0', 'Costo de envío': '34400.0', 'Fecha de Compra': '05/06/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Mochila', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '111000.0', 'Costo de envío': '4100.0', 'Fecha de Compra': '01/02/2022', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Tablet ABXY', 'Categoría del Producto': 'Electrónicos', 'Precio': '1196000.0', 'Costo de envío': '61900.0', 'Fecha de Compra': '04/03/2023', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Balón de baloncesto', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '45100.0', 'Costo de envío': '7100.0', 'Fecha de Compra': '28/01/2021', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Bucaramanga', 'Calificación': '4', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '7.12539', 'lon': '-73.1198'}
# {'Producto': 'Mesa de noche', 'Categoría del Producto': 'Muebles', 'Precio': '284200.0', 'Costo de envío': '16400.0', 'Fecha de Compra': '17/07/2022', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Cali', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Armario', 'Categoría del Producto': 'Muebles', 'Precio': '490400.0', 'Costo de envío': '24300.0', 'Fecha de Compra': '06/09/2021', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Auriculares con micrófono', 'Categoría del Producto': 'Electrónicos', 'Precio': '143600.0', 'Costo de envío': '7900.0', 'Fecha de Compra': '01/05/2020', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Auriculares', 'Categoría del Producto': 'Electrónicos', 'Precio': '139100.0', 'Costo de envío': '7600.0', 'Fecha de Compra': '28/10/2022', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Valledupar', 'Calificación': '2', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '10.46314', 'lon': '-73.25322'}
# {'Producto': 'Carrito de control remoto', 'Categoría del Producto': 'Juguetes', 'Precio': '84600.0', 'Costo de envío': '4900.0', 'Fecha de Compra': '02/11/2021', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Batería', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '401900.0', 'Costo de envío': '19600.0', 'Fecha de Compra': '01/03/2023', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '2172400.0', 'Costo de envío': '113900.0', 'Fecha de Compra': '11/09/2022', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Sillón', 'Categoría del Producto': 'Muebles', 'Precio': '296400.0', 'Costo de envío': '14000.0', 'Fecha de Compra': '23/01/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Barranquilla', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '10.96854', 'lon': '-74.78132'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '368700.0', 'Costo de envío': '19800.0', 'Fecha de Compra': '10/12/2020', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '130800.0', 'Costo de envío': '5200.0', 'Fecha de Compra': '02/10/2021', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '1396500.0', 'Costo de envío': '74800.0', 'Fecha de Compra': '23/04/2020', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '9', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Balón de baloncesto', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '42100.0', 'Costo de envío': '6900.0', 'Fecha de Compra': '27/10/2022', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Cartagena', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '10.39972', 'lon': '-75.51444'}
# {'Producto': 'Muñeca bebé', 'Categoría del Producto': 'Juguetes', 'Precio': '44800.0', 'Costo de envío': '2600.0', 'Fecha de Compra': '20/12/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Pasto', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '1.21361', 'lon': '-77.28111'}
# {'Producto': 'Set de vasos', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '35300.0', 'Costo de envío': '2300.0', 'Fecha de Compra': '23/07/2020', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '444800.0', 'Costo de envío': '24100.0', 'Fecha de Compra': '05/05/2022', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '412500.0', 'Costo de envío': '20200.0', 'Fecha de Compra': '29/07/2021', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '7', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '59800.0', 'Costo de envío': '4200.0', 'Fecha de Compra': '30/12/2020', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Muñeca bebé', 'Categoría del Producto': 'Juguetes', 'Precio': '42000.0', 'Costo de envío': '0.0', 'Fecha de Compra': '22/01/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '7', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Impresora', 'Categoría del Producto': 'Electrónicos', 'Precio': '288300.0', 'Costo de envío': '13500.0', 'Fecha de Compra': '16/05/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Guitarra acústica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '434600.0', 'Costo de envío': '23500.0', 'Fecha de Compra': '28/06/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Kit de bancas', 'Categoría del Producto': 'Muebles', 'Precio': '245600.0', 'Costo de envío': '11300.0', 'Fecha de Compra': '24/09/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Valledupar', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '10.46314', 'lon': '-73.25322'}
# {'Producto': 'Modelado predictivo', 'Categoría del Producto': 'Libros', 'Precio': '53800.0', 'Costo de envío': '1100.0', 'Fecha de Compra': '20/03/2023', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '722600.0', 'Costo de envío': '36700.0', 'Fecha de Compra': '30/09/2021', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Cúcuta', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '7.89391', 'lon': '-72.50782'}
# {'Producto': 'Olla de presión', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '78300.0', 'Costo de envío': '4600.0', 'Fecha de Compra': '27/09/2022', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Mesa de comedor', 'Categoría del Producto': 'Muebles', 'Precio': '279300.0', 'Costo de envío': '15300.0', 'Fecha de Compra': '03/05/2022', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Bogotá', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '6', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Bicicleta', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '475100.0', 'Costo de envío': '23500.0', 'Fecha de Compra': '13/12/2020', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Olla de presión', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '72600.0', 'Costo de envío': '2100.0', 'Fecha de Compra': '10/02/2022', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Iniciando en programación', 'Categoría del Producto': 'Libros', 'Precio': '49400.0', 'Costo de envío': '3300.0', 'Fecha de Compra': '01/04/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cuerda para saltar', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '22800.0', 'Costo de envío': '7300.0', 'Fecha de Compra': '20/10/2020', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de débito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Muñeca bebé', 'Categoría del Producto': 'Juguetes', 'Precio': '54600.0', 'Costo de envío': '1100.0', 'Fecha de Compra': '27/01/2022', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Dashboards con Power BI', 'Categoría del Producto': 'Libros', 'Precio': '33500.0', 'Costo de envío': '0.0', 'Fecha de Compra': '29/07/2021', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Celular ABXY', 'Categoría del Producto': 'Electrónicos', 'Precio': '701900.0', 'Costo de envío': '35600.0', 'Fecha de Compra': '11/01/2020', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Secadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1438900.0', 'Costo de envío': '77300.0', 'Fecha de Compra': '06/02/2020', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Auriculares con micrófono', 'Categoría del Producto': 'Electrónicos', 'Precio': '55300.0', 'Costo de envío': '4000.0', 'Fecha de Compra': '04/07/2021', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Muñeca bebé', 'Categoría del Producto': 'Juguetes', 'Precio': '53200.0', 'Costo de envío': '3100.0', 'Fecha de Compra': '28/12/2020', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Riohacha', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '11.54444', 'lon': '-72.90722'}
# {'Producto': 'Sillón', 'Categoría del Producto': 'Muebles', 'Precio': '222500.0', 'Costo de envío': '12400.0', 'Fecha de Compra': '14/02/2020', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Bicicleta', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '535900.0', 'Costo de envío': '29200.0', 'Fecha de Compra': '11/10/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Smartwatch', 'Categoría del Producto': 'Electrónicos', 'Precio': '172300.0', 'Costo de envío': '9400.0', 'Fecha de Compra': '11/02/2022', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Ciencia de datos con Python', 'Categoría del Producto': 'Libros', 'Precio': '39700.0', 'Costo de envío': '2300.0', 'Fecha de Compra': '18/05/2022', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '66900.0', 'Costo de envío': '5900.0', 'Fecha de Compra': '06/07/2022', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '2761500.0', 'Costo de envío': '147300.0', 'Fecha de Compra': '15/12/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '555800.0', 'Costo de envío': '29800.0', 'Fecha de Compra': '04/12/2021', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Refrigerador', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '2185100.0', 'Costo de envío': '114500.0', 'Fecha de Compra': '09/02/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Dashboards con Power BI', 'Categoría del Producto': 'Libros', 'Precio': '44400.0', 'Costo de envío': '0.0', 'Fecha de Compra': '15/04/2020', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Cartagena', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '10.39972', 'lon': '-75.51444'}
# {'Producto': 'Bloques de construcción', 'Categoría del Producto': 'Juguetes', 'Precio': '30900.0', 'Costo de envío': '0.0', 'Fecha de Compra': '05/03/2020', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Villavicencio', 'Calificación': '2', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.142', 'lon': '-73.62664'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '2824600.0', 'Costo de envío': '150600.0', 'Fecha de Compra': '07/09/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Pasto', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '1.21361', 'lon': '-77.28111'}
# {'Producto': 'Lavavajillas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1527900.0', 'Costo de envío': '82000.0', 'Fecha de Compra': '04/08/2020', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '2', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Mesa de centro', 'Categoría del Producto': 'Muebles', 'Precio': '182800.0', 'Costo de envío': '10100.0', 'Fecha de Compra': '25/11/2022', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Microondas', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '714200.0', 'Costo de envío': '38400.0', 'Fecha de Compra': '27/07/2020', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Olla de presión', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '83300.0', 'Costo de envío': '2600.0', 'Fecha de Compra': '17/01/2020', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '10', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '35000.0', 'Costo de envío': '2600.0', 'Fecha de Compra': '12/09/2020', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cama king', 'Categoría del Producto': 'Muebles', 'Precio': '695100.0', 'Costo de envío': '37200.0', 'Fecha de Compra': '23/01/2022', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Modelado predictivo', 'Categoría del Producto': 'Libros', 'Precio': '69700.0', 'Costo de envío': '10500.0', 'Fecha de Compra': '15/04/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Lavadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1356900.0', 'Costo de envío': '74600.0', 'Fecha de Compra': '02/01/2020', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Pasto', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '1.21361', 'lon': '-77.28111'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '2351400.0', 'Costo de envío': '129900.0', 'Fecha de Compra': '17/02/2020', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Bucaramanga', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '7.12539', 'lon': '-73.1198'}
# {'Producto': 'Guitarra acústica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '204600.0', 'Costo de envío': '9100.0', 'Fecha de Compra': '28/05/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '2910000.0', 'Costo de envío': '153100.0', 'Fecha de Compra': '02/07/2021', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Olla de presión', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '62400.0', 'Costo de envío': '1500.0', 'Fecha de Compra': '01/04/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Secadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1090800.0', 'Costo de envío': '56300.0', 'Fecha de Compra': '01/09/2022', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Sillón', 'Categoría del Producto': 'Muebles', 'Precio': '262500.0', 'Costo de envío': '14400.0', 'Fecha de Compra': '06/09/2022', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Modelado predictivo', 'Categoría del Producto': 'Libros', 'Precio': '55600.0', 'Costo de envío': '4000.0', 'Fecha de Compra': '26/12/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Cartagena', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '10.39972', 'lon': '-75.51444'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '1927400.0', 'Costo de envío': '108500.0', 'Fecha de Compra': '17/11/2022', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Dashboards con Power BI', 'Categoría del Producto': 'Libros', 'Precio': '30500.0', 'Costo de envío': '0.0', 'Fecha de Compra': '06/04/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bucaramanga', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '7.12539', 'lon': '-73.1198'}
# {'Producto': 'Armario', 'Categoría del Producto': 'Muebles', 'Precio': '508100.0', 'Costo de envío': '25200.0', 'Fecha de Compra': '03/02/2023', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '503700.0', 'Costo de envío': '27000.0', 'Fecha de Compra': '30/01/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Auriculares con micrófono', 'Categoría del Producto': 'Electrónicos', 'Precio': '161600.0', 'Costo de envío': '9000.0', 'Fecha de Compra': '21/10/2022', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '2872800.0', 'Costo de envío': '151200.0', 'Fecha de Compra': '05/02/2020', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Set de vasos', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '34000.0', 'Costo de envío': '2000.0', 'Fecha de Compra': '26/10/2021', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Pereira', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.81333', 'lon': '-75.69611'}
# ...
# {'Producto': 'Auriculares', 'Categoría del Producto': 'Electrónicos', 'Precio': '103300.0', 'Costo de envío': '5900.0', 'Fecha de Compra': '26/10/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Sillón', 'Categoría del Producto': 'Muebles', 'Precio': '254400.0', 'Costo de envío': '11700.0', 'Fecha de Compra': '14/10/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '6', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Guitarra eléctrica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '676600.0', 'Costo de envío': '34200.0', 'Fecha de Compra': '18/12/2022', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '2645600.0', 'Costo de envío': '139100.0', 'Fecha de Compra': '18/01/2023', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '290000.0', 'Costo de envío': '13600.0', 'Fecha de Compra': '27/03/2022', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Armenia', 'Calificación': '3', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '4.53389', 'lon': '-75.68111'}
# {'Producto': 'Refrigerador', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '2311300.0', 'Costo de envío': '121300.0', 'Fecha de Compra': '13/02/2022', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Villavicencio', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.142', 'lon': '-73.62664'}
# {'Producto': 'TV LED UHD 4K', 'Categoría del Producto': 'Electrónicos', 'Precio': '1598900.0', 'Costo de envío': '85700.0', 'Fecha de Compra': '12/09/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Guitarra eléctrica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '953200.0', 'Costo de envío': '48900.0', 'Fecha de Compra': '18/01/2020', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Mesa de centro', 'Categoría del Producto': 'Muebles', 'Precio': '125100.0', 'Costo de envío': '6900.0', 'Fecha de Compra': '26/09/2022', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Set de ollas', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '184100.0', 'Costo de envío': '8000.0', 'Fecha de Compra': '15/05/2021', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Medellín', 'Calificación': '2', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Bloques de construcción', 'Categoría del Producto': 'Juguetes', 'Precio': '31600.0', 'Costo de envío': '0.0', 'Fecha de Compra': '25/03/2021', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Ciencia de datos con Python', 'Categoría del Producto': 'Libros', 'Precio': '68700.0', 'Costo de envío': '3900.0', 'Fecha de Compra': '24/11/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Celular ABXY', 'Categoría del Producto': 'Electrónicos', 'Precio': '881900.0', 'Costo de envío': '47200.0', 'Fecha de Compra': '12/11/2021', 'Vendedor': 'Camila Rivera', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Mesa de noche', 'Categoría del Producto': 'Muebles', 'Precio': '327800.0', 'Costo de envío': '15600.0', 'Fecha de Compra': '22/07/2021', 'Vendedor': 'Ángel Rodriguez', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Cupón', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Smartwatch', 'Categoría del Producto': 'Electrónicos', 'Precio': '194700.0', 'Costo de envío': '12700.0', 'Fecha de Compra': '06/07/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Barranquilla', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '10.96854', 'lon': '-74.78132'}
# {'Producto': 'Lavadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1434300.0', 'Costo de envío': '76800.0', 'Fecha de Compra': '06/10/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Pasto', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '1.21361', 'lon': '-77.28111'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '32600.0', 'Costo de envío': '0.0', 'Fecha de Compra': '24/12/2020', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Bloques de construcción', 'Categoría del Producto': 'Juguetes', 'Precio': '25100.0', 'Costo de envío': '1600.0', 'Fecha de Compra': '05/12/2020', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Leticia', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '-4.21528', 'lon': '-69.94056'}
# {'Producto': 'Asistente virtual', 'Categoría del Producto': 'Electrónicos', 'Precio': '280000.0', 'Costo de envío': '15100.0', 'Fecha de Compra': '17/09/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Refrigerador', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '2392700.0', 'Costo de envío': '125600.0', 'Fecha de Compra': '30/04/2020', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Asistente virtual', 'Categoría del Producto': 'Electrónicos', 'Precio': '263500.0', 'Costo de envío': '15300.0', 'Fecha de Compra': '04/04/2022', 'Vendedor': 'Juan Fernandez', 'Lugar de Compra': 'Pereira', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.81333', 'lon': '-75.69611'}
# {'Producto': 'Cama king', 'Categoría del Producto': 'Muebles', 'Precio': '855700.0', 'Costo de envío': '45800.0', 'Fecha de Compra': '27/03/2021', 'Vendedor': 'Juliana Costa', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cubertería', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '38000.0', 'Costo de envío': '7700.0', 'Fecha de Compra': '24/03/2023', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Santa Marta', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '11.24079', 'lon': '-74.19904'}
# {'Producto': 'Cuerda para saltar', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '8100.0', 'Costo de envío': '0.0', 'Fecha de Compra': '11/03/2020', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '6', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Armario', 'Categoría del Producto': 'Muebles', 'Precio': '478300.0', 'Costo de envío': '23700.0', 'Fecha de Compra': '02/02/2023', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Iniciando en programación', 'Categoría del Producto': 'Libros', 'Precio': '49100.0', 'Costo de envío': '800.0', 'Fecha de Compra': '09/12/2021', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Pereira', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '3', 'lat': '4.81333', 'lon': '-75.69611'}
# {'Producto': 'Lavadora de ropa', 'Categoría del Producto': 'Electrodomésticos', 'Precio': '1356700.0', 'Costo de envío': '70400.0', 'Fecha de Compra': '26/10/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Auriculares con micrófono', 'Categoría del Producto': 'Electrónicos', 'Precio': '48000.0', 'Costo de envío': '0.0', 'Fecha de Compra': '24/03/2022', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Balón de baloncesto', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '62800.0', 'Costo de envío': '1500.0', 'Fecha de Compra': '16/10/2021', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Set de vasos', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '32600.0', 'Costo de envío': '0.0', 'Fecha de Compra': '28/05/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Asistente virtual', 'Categoría del Producto': 'Electrónicos', 'Precio': '227800.0', 'Costo de envío': '10300.0', 'Fecha de Compra': '21/11/2022', 'Vendedor': 'Beatriz Morales', 'Lugar de Compra': 'Pereira', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '5', 'lat': '4.81333', 'lon': '-75.69611'}
# {'Producto': 'Cama king', 'Categoría del Producto': 'Muebles', 'Precio': '448500.0', 'Costo de envío': '24300.0', 'Fecha de Compra': '04/02/2023', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cama king', 'Categoría del Producto': 'Muebles', 'Precio': '782000.0', 'Costo de envío': '39800.0', 'Fecha de Compra': '23/03/2020', 'Vendedor': 'Mariana Herrera', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '1306500.0', 'Costo de envío': '71900.0', 'Fecha de Compra': '11/02/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Guitarra acústica', 'Categoría del Producto': 'Instrumentos musicales', 'Precio': '319300.0', 'Costo de envío': '15200.0', 'Fecha de Compra': '11/05/2020', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '8', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cubertería', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '57200.0', 'Costo de envío': '3400.0', 'Fecha de Compra': '18/11/2020', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Bogotá', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '6', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Vaso térmico', 'Categoría del Producto': 'Deportes y diversión', 'Precio': '28300.0', 'Costo de envío': '0.0', 'Fecha de Compra': '25/03/2020', 'Vendedor': 'Blanca Ramirez', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cubertería', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '35700.0', 'Costo de envío': '0.0', 'Fecha de Compra': '29/06/2020', 'Vendedor': 'Santiago Silva', 'Lugar de Compra': 'Medellín', 'Calificación': '4', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Carrito de control remoto', 'Categoría del Producto': 'Juguetes', 'Precio': '68900.0', 'Costo de envío': '1900.0', 'Fecha de Compra': '05/03/2023', 'Vendedor': 'Maria Alfonso', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Silla de oficina', 'Categoría del Producto': 'Muebles', 'Precio': '489300.0', 'Costo de envío': '28400.0', 'Fecha de Compra': '10/12/2020', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Cama king', 'Categoría del Producto': 'Muebles', 'Precio': '507900.0', 'Costo de envío': '32900.0', 'Fecha de Compra': '10/02/2021', 'Vendedor': 'Rafael Acosta', 'Lugar de Compra': 'Medellín', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Cubertería', 'Categoría del Producto': 'Artículos para el hogar', 'Precio': '40500.0', 'Costo de envío': '0.0', 'Fecha de Compra': '30/12/2022', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Iphone 15', 'Categoría del Producto': 'Electrónicos', 'Precio': '1284400.0', 'Costo de envío': '66600.0', 'Fecha de Compra': '15/11/2021', 'Vendedor': 'Izabela de León', 'Lugar de Compra': 'Medellín', 'Calificación': '1', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '6.25184', 'lon': '-75.56359'}
# {'Producto': 'Impresora', 'Categoría del Producto': 'Electrónicos', 'Precio': '282800.0', 'Costo de envío': '15300.0', 'Fecha de Compra': '18/03/2023', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Bogotá', 'Calificación': '5', 'Método de pago': 'Nequi', 'Cantidad de cuotas': '1', 'lat': '4.60971', 'lon': '-74.08175'}
# {'Producto': 'Juego de mesa', 'Categoría del Producto': 'Juguetes', 'Precio': '122900.0', 'Costo de envío': '7200.0', 'Fecha de Compra': '06/07/2021', 'Vendedor': 'Lucas Olivera', 'Lugar de Compra': 'Cali', 'Calificación': '5', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '4', 'lat': '3.43722', 'lon': '-76.5225'}
# {'Producto': 'Cama box', 'Categoría del Producto': 'Muebles', 'Precio': '691300.0', 'Costo de envío': '35000.0', 'Fecha de Compra': '02/05/2022', 'Vendedor': 'Pedro Gomez', 'Lugar de Compra': 'Pasto', 'Calificación': '1', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '2', 'lat': '1.21361', 'lon': '-77.28111'}
# {'Producto': 'Smartwatch', 'Categoría del Producto': 'Electrónicos', 'Precio': '195000.0', 'Costo de envío': '8600.0', 'Fecha de Compra': '18/06/2022', 'Vendedor': 'Felipe Santos', 'Lugar de Compra': 'Cali', 'Calificación': '4', 'Método de pago': 'Tarjeta de crédito', 'Cantidad de cuotas': '1', 'lat': '3.43722', 'lon': '-76.5225'}

# %%
from urllib.request import urlopen
import csv

urls = [url, url2, url3, url4]


print(list(enumerate(urls)))
# Out:
# [(0, 'https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv'), (1, 'https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv'), (2, 'https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv'), (3, 'https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv')]

# %% [markdown]
# #1. Análisis de facturación

# %%
from urllib.request import urlopen
import csv

urls = [url, url2, url3, url4]

# Función para leer un CSV desde URL
def leer_csv(url):
    datos = []
    with urlopen(url) as respuesta:
        lineas = respuesta.read().decode('utf-8').splitlines()
        lector = csv.DictReader(lineas)
        for fila in lector:
            datos.append(fila)
    return datos

# Análisis de facturación
total_facturacion = 0

for i, url in enumerate(urls):
    datos_tienda = leer_csv(url)
    facturacion_tienda = 0

    for venta in datos_tienda:
        precio = float(venta['Precio'])  # Solo sumamos el precio
        facturacion_tienda += precio

    print(f"Facturación Tienda {i+1}: ${facturacion_tienda:.2f}")
    total_facturacion += facturacion_tienda

# Mostrar facturación total
print(f"\nFacturación total de todas las tiendas: ${total_facturacion:.2f}")
# Out:
# Facturación Tienda 1: $1150880400.00
# Facturación Tienda 2: $1116343500.00
# Facturación Tienda 3: $1098019600.00
# Facturación Tienda 4: $1038375700.00
#
# Facturación total de todas las tiendas: $4403619200.00

# %%
# Sumando solo el precio de las ventas, sin considerar las cuotas
facturacion_tienda1 = tienda['Precio'].astype(float).sum()
facturacion_tienda2 = tienda2['Precio'].astype(float).sum()
facturacion_tienda3 = tienda3['Precio'].astype(float).sum()
facturacion_tienda4 = tienda4['Precio'].astype(float).sum()

# Mostrar los resultados
print(f"Facturación Tienda 1: ${facturacion_tienda1:.2f}")
print(f"Facturación Tienda 2: ${facturacion_tienda2:.2f}")
print(f"Facturación Tienda 3: ${facturacion_tienda3:.2f}")
print(f"Facturación Tienda 4: ${facturacion_tienda4:.2f}")

# Facturación total de todas las tiendas
facturacion_total = facturacion_tienda1 + facturacion_tienda2 + facturacion_tienda3 + facturacion_tienda4
print(f"\nFacturación total de todas las tiendas: ${facturacion_total:.2f}")
# Out:
# Facturación Tienda 1: $1150880400.00
# Facturación Tienda 2: $1116343500.00
# Facturación Tienda 3: $1098019600.00
# Facturación Tienda 4: $1038375700.00
#
# Facturación total de todas las tiendas: $4403619200.00

# %% [markdown]
# # 2. Ventas por categoría

# %%
def leer_csv(url):
    datos = []
    with urlopen(url) as respuesta:
        # Decodificar los datos
        lineas = respuesta.read().decode('utf-8').splitlines()
        reader = csv.DictReader(lineas)
        for fila in reader:
            datos.append(fila)
    return datos

# Diccionario para almacenar las ventas por categoría
ventas_por_categoria = {}

# Procesar todas las tiendas
for i, url in enumerate(urls):
    datos_tienda = leer_csv(url)
    print(f"\nVentas por categoría en Tienda {i+1}:")

    # Diccionario para la tienda actual
    categorias_tienda = {}

    for venta in datos_tienda:
        categoria = venta['Categoría del Producto']
        precio = float(venta['Precio'])
        cantidad = int(venta['Cantidad de cuotas'])
        monto_venta = precio * cantidad

        # Agregar al diccionario de la tienda actual
        if categoria in categorias_tienda:
            categorias_tienda[categoria] += monto_venta
        else:
            categorias_tienda[categoria] = monto_venta

        # Agregar al diccionario general
        if categoria in ventas_por_categoria:
            ventas_por_categoria[categoria] += monto_venta
        else:
            ventas_por_categoria[categoria] = monto_venta

    # Mostrar resultados para esta tienda
    for categoria, monto in categorias_tienda.items():
        print(f"  {categoria}: ${monto:.2f}")

# Mostrar resultados totales
print("\nVentas totales por categoría (todas las tiendas):")
for categoria, monto in ventas_por_categoria.items():
    print(f"  {categoria}: ${monto:.2f}")

# Calcular el total general
total_general = sum(ventas_por_categoria.values())
print(f"\nTotal general de ventas: ${total_general:.2f}")
# Out:
# Ventas por categoría en Tienda 1:
#   Electrónicos: $1290390700.00
#   Muebles: $582928200.00
#   Juguetes: $49062800.00
#   Electrodomésticos: $1032375600.00
#   Artículos para el hogar: $38316800.00
#   Deportes y diversión: $126883700.00
#   Libros: $25769400.00
#   Instrumentos musicales: $276990500.00
#
# Ventas por categoría en Tienda 2:
#   Muebles: $527332100.00
#   Instrumentos musicales: $294448700.00
#   Deportes y diversión: $81660600.00
#   Electrónicos: $1286643600.00
#   Artículos para el hogar: $42739700.00
#   Juguetes: $46721200.00
#   Electrodomésticos: $1026226300.00
#   Libros: $31417000.00
#
# Ventas por categoría en Tienda 3:
#   Electrodomésticos: $1081380800.00
#   Muebles: $555092500.00
#   Instrumentos musicales: $250336000.00
#   Deportes y diversión: $123399200.00
#   Electrónicos: $1101334500.00
#   Juguetes: $61190400.00
#   Artículos para el hogar: $44724600.00
#   Libros: $26358900.00
#
# Ventas por categoría en Tienda 4:
#   Electrodomésticos: $879089600.00
#   Muebles: $556628000.00
#   Deportes y diversión: $100062000.00
#   Libros: $29543400.00
#   Electrónicos: $1211446500.00
#   Instrumentos musicales: $222837200.00
#   Juguetes: $54641200.00
#   Artículos para el hogar: $44579300.00
#
# Ventas totales por categoría (todas las tiendas):
#   Electrónicos: $4889815300.00
#   Muebles: $2221980800.00
#   Juguetes: $211615600.00
#   Electrodomésticos: $4019072300.00
#   Artículos para el hogar: $170360400.00
#   Deportes y diversión: $432005500.00
#   Libros: $113088700.00
#   Instrumentos musicales: $1044612400.00
#
# Total general de ventas: $13102551000.00

# %%
# Función para calcular y mostrar las ventas por categoría de una tienda
def ventas_por_categoria(tienda, numero):
    ventas = tienda.groupby('Categoría del Producto')['Precio'].sum()
    print(f"\nVentas por categoría en Tienda {numero}:")
    print(ventas)

# Mostrar resultados para cada tienda
ventas_por_categoria(tienda, 1)
ventas_por_categoria(tienda2, 2)
ventas_por_categoria(tienda3, 3)
ventas_por_categoria(tienda4, 4)
# Out:
# Ventas por categoría en Tienda 1:
# Categoría del Producto
# Artículos para el hogar     12698400.0
# Deportes y diversión        39290000.0
# Electrodomésticos          363685200.0
# Electrónicos               429493500.0
# Instrumentos musicales      91299000.0
# Juguetes                    17995700.0
# Libros                       8784900.0
# Muebles                    187633700.0
# Name: Precio, dtype: float64
#
# Ventas por categoría en Tienda 2:
# Categoría del Producto
# Artículos para el hogar     14746900.0
# Deportes y diversión        34744500.0
# Electrodomésticos          348567800.0
# Electrónicos               410831100.0
# Instrumentos musicales     104990300.0
# Juguetes                    15945400.0
# Libros                      10091200.0
# Muebles                    176426300.0
# Name: Precio, dtype: float64
#
# Ventas por categoría en Tienda 3:
# Categoría del Producto
# Artículos para el hogar     15060000.0
# Deportes y diversión        35593100.0
# Electrodomésticos          329237900.0
# Electrónicos               410775800.0
# Instrumentos musicales      77380900.0
# Juguetes                    19401100.0
# Libros                       9498700.0
# Muebles                    201072100.0
# Name: Precio, dtype: float64
#
# Ventas por categoría en Tienda 4:
# Categoría del Producto
# Artículos para el hogar     15074500.0
# Deportes y diversión        33350100.0
# Electrodomésticos          283260200.0
# Electrónicos               409476100.0
# Instrumentos musicales      75102400.0
# Juguetes                    20262200.0
# Libros                       9321300.0
# Muebles                    192528900.0
# Name: Precio, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
def leer_csv(url):
    datos = []
    with urlopen(url) as respuesta:
        # Decodificar los datos
        lineas = respuesta.read().decode('utf-8').splitlines()
        reader = csv.DictReader(lineas)
        for fila in reader:
            datos.append(fila)
    return datos

# Calcular la calificación promedio para cada tienda
for i, url in enumerate(urls):
    datos_tienda = leer_csv(url)

    # Variables para calcular el promedio
    suma_calificaciones = 0
    cantidad_productos = 0

    for producto in datos_tienda:
        try:
            # Intentamos con diferentes posibles nombres de columna
            if 'Calificación' in producto:
                calificacion = float(producto['Calificación'])
            elif 'Calificacion' in producto:
                calificacion = float(producto['Calificacion'])
            elif 'calificación' in producto:
                calificacion = float(producto['calificación'])
            elif 'calificacion' in producto:
                calificacion = float(producto['calificacion'])
            else:
                # Si no encontramos la columna, imprimimos las claves disponibles
                print(f"Claves disponibles en la tienda {i+1}:", producto.keys())
                raise KeyError("No se encontró la columna de calificación")

            suma_calificaciones += calificacion
            cantidad_productos += 1
        except (ValueError, KeyError) as e:
            if isinstance(e, KeyError):
                raise
            # Ignoramos valores que no se pueden convertir a float
            continue

    if cantidad_productos > 0:
        calificacion_promedio = suma_calificaciones / cantidad_productos
        print(f"Calificación promedio de la Tienda {i+1}: {calificacion_promedio:.2f}")
    else:
        print(f"No se pudieron procesar calificaciones para la Tienda {i+1}")
# Out:
# Calificación promedio de la Tienda 1: 3.98
# Calificación promedio de la Tienda 2: 4.04
# Calificación promedio de la Tienda 3: 4.05
# Calificación promedio de la Tienda 4: 4.00

# %%
def clasificacion_promedio(tienda, numero):
    promedio = tienda['Calificación'].mean()
    print(f"Clasificación promedio en Tienda {numero}: {promedio:.2f}")

# Mostrar resultados para cada tienda
clasificacion_promedio(tienda, 1)
clasificacion_promedio(tienda2, 2)
clasificacion_promedio(tienda3, 3)
clasificacion_promedio(tienda4, 4)
# Out:
# Clasificación promedio en Tienda 1: 3.98
# Clasificación promedio en Tienda 2: 4.04
# Clasificación promedio en Tienda 3: 4.05
# Clasificación promedio en Tienda 4: 4.00

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
def leer_csv(url):
    datos = []
    with urlopen(url) as respuesta:
        lineas = respuesta.read().decode('utf-8').splitlines()
        lector = csv.DictReader(lineas)
        for fila in lector:
            datos.append(fila)
    return datos

#Importamos la función deafultdict del módulo collections para crear un diccionario que asigne como valor 0.0 a las claves que no están presentes en él
from collections import defaultdict

# Función para calcular Top 3 más y menos dinero generado
def top_productos(datos_tienda, tienda_numero):
    '''
    # Alternativa 1 al uso de defaultdict
    ingreso_por_producto = {}

        # Agregar al diccionario de la tienda actual
        if producto in ingreso_por_producto:
            ingreso_por_producto[producto] += precio
        else:
            ingreso_por_producto[producto] = precio

    # Alternativa 2 al uso de defaultdict:
    if producto not in ingreso_por_producto:
        ingreso_por_producto[producto] = 0.0
    ingreso_por_producto[producto] += precio

    '''
    ingreso_por_producto = defaultdict(float)

    for venta in datos_tienda:
        producto = venta['Producto']
        precio = float(venta['Precio'])
        # Ahora solo usamos el precio (no multiplicamos por cantidad de cuotas)
        ingreso_por_producto[producto] += precio

    # Convertimos a lista ordenada
    # ingreso_por_producto.items() Convierte el diccionario en una lista de tupla. 
    # Si el iterable es una lista de tuplas, entonces el resultado será una lista de tuplas ordenadas.
    productos_ordenados = sorted(ingreso_por_producto.items(), key=lambda x: x[1], reverse=True)

    top_mas_vendidos = productos_ordenados[:3]
    top_menos_vendidos = productos_ordenados[-3:]

    print(f"\nTienda {tienda_numero} - TOP 3 productos que MÁS dinero generaron:")
    for producto, ingreso in top_mas_vendidos:
        print(f"  {producto} - Ingresos: ${ingreso:.2f}")

    print(f"\nTienda {tienda_numero} - TOP 3 productos que MENOS dinero generaron:")
    for producto, ingreso in top_menos_vendidos:
        print(f"  {producto} - Ingresos: ${ingreso:.2f}")

# Recorrer todas las tiendas
for i, url in enumerate(urls, start=1):
    datos_tienda = leer_csv(url)
    top_productos(datos_tienda, i)
# Out:
# Tienda 1 - TOP 3 productos que MÁS dinero generaron:
#   TV LED UHD 4K - Ingresos: $142150200.00
#   Refrigerador - Ingresos: $112143300.00
#   Iphone 15 - Ingresos: $97902200.00
#
# Tienda 1 - TOP 3 productos que MENOS dinero generaron:
#   Cubo mágico 8x8 - Ingresos: $696900.00
#   Dinosaurio Rex - Ingresos: $688900.00
#   Cuerda para saltar - Ingresos: $652800.00
#
# Tienda 2 - TOP 3 productos que MÁS dinero generaron:
#   Iphone 15 - Ingresos: $113225800.00
#   TV LED UHD 4K - Ingresos: $103375000.00
#   Refrigerador - Ingresos: $97632500.00
#
# Tienda 2 - TOP 3 productos que MENOS dinero generaron:
#   Cuerda para saltar - Ingresos: $856900.00
#   Dinosaurio Rex - Ingresos: $770300.00
#   Cubo mágico 8x8 - Ingresos: $643600.00
#
# Tienda 3 - TOP 3 productos que MÁS dinero generaron:
#   Refrigerador - Ingresos: $99889700.00
#   TV LED UHD 4K - Ingresos: $96669100.00
#   Iphone 15 - Ingresos: $93225700.00
#
# Tienda 3 - TOP 3 productos que MENOS dinero generaron:
#   Cuerda para saltar - Ingresos: $853800.00
#   Dinosaurio Rex - Ingresos: $795600.00
#   Cubo mágico 8x8 - Ingresos: $640400.00
#
# Tienda 4 - TOP 3 productos que MÁS dinero generaron:
#   Iphone 15 - Ingresos: $96697500.00
#   TV LED UHD 4K - Ingresos: $90295300.00
#   Smart TV - Ingresos: $82790400.00
#
# Tienda 4 - TOP 3 productos que MENOS dinero generaron:
#   Dinosaurio Rex - Ingresos: $858100.00
#   Cubo mágico 8x8 - Ingresos: $748400.00
#   Cuerda para saltar - Ingresos: $704800.00

# %%
# Leer todos los CSVs y agregar una columna 'Tienda' 
# assign crea una nueva columna en el DataFrame original sin modificarlo.
# la iteración for le dicta a concat los dataframe que va a unir
# ignore_index=True: reinicia el índice del DF resultante en lugar de mantener los índices originales de cada DF
# Por defecto concat une los DF de forma vertical. En caso se desee unir de forma horizontal, se debe especificar que el eje es 1 (axis =1)
df_total = pd.concat(
    [pd.read_csv(url).assign(Tienda=f"Tienda {i+1}") for i, url in enumerate(urls)],
    ignore_index=True
)

# Aseguramos los tipos correctos
df_total['Precio'] = df_total['Precio'].astype(float)
df_total['Cantidad de cuotas'] = df_total['Cantidad de cuotas'].astype(int)

# El ingreso es simplemente el Precio (no multiplicamos por cantidad de cuotas)
df_total['Ingreso'] = df_total['Precio']

# Agrupamos por Tienda y Producto sumando el ingreso
# reset_index() transforma los índices actuales (campos bajo los que estamos agrupando los datos, Tienda y Producto) en una columna normal.
# El nuevo índice será un rango automático (con en los anteriores DF)
ventas = df_total.groupby(['Tienda', 'Producto'])['Ingreso'].sum().reset_index() 

# Función para mostrar los 3 productos que más y menos dinero generaron
def top_productos(tienda):
    data = ventas[ventas['Tienda'] == tienda] # El doble igual no está asignando, sino comparando si los valores de la columna Tienda son iguales a la variable Tienda
                                              # ventas['Tienda'] == tienda devuelve una serie booleana (True o False).
                                              # ventas[...] filtra solo las filas donde esa comparación sea True.
                                              # A esto se le llama filtrado booleano o indexación booleana, uno de los métodos más poderosos de Panda

    top_mas_vendidos = data.sort_values(by='Ingreso', ascending=False).head(3)
    top_menos_vendidos = data.sort_values(by='Ingreso', ascending=True).head(3)

    print(f"\n{tienda} - TOP 3 productos que MÁS dinero generaron:") 
    # iterrows() recorre el DataFrame fila por fila, devolviendo una tupla (índice, fila) 
    # fila es una Serie (pd.Series) que representa una fila del DF, y se comporta como un diccionario
    # Por eso puedes acceder a fila['Producto'] o fila['Ingreso'].
    # El guión bajo _ es una convención en Python que significa: "no voy a usar esta variable".
    # Aquí solo interesa la fila (fila), así que el índice se ignora.
    for _, fila in top_mas_vendidos.iterrows(): 
        print(f"  {fila['Producto']} - Ingresos: ${fila['Ingreso']:.2f}")

    print(f"\n{tienda} - TOP 3 productos que MENOS dinero generaron:")
    for _, fila in top_menos_vendidos.iterrows():
        print(f"  {fila['Producto']} - Ingresos: ${fila['Ingreso']:.2f}")

# Lista única de tiendas
tiendas_unicas = ventas['Tienda'].unique()

# Mostrar resultados para cada tienda
for tienda in tiendas_unicas:
    top_productos(tienda)
# Out:
# Tienda 1 - TOP 3 productos que MÁS dinero generaron:
#   TV LED UHD 4K - Ingresos: $142150200.00
#   Refrigerador - Ingresos: $112143300.00
#   Iphone 15 - Ingresos: $97902200.00
#
# Tienda 1 - TOP 3 productos que MENOS dinero generaron:
#   Cuerda para saltar - Ingresos: $652800.00
#   Dinosaurio Rex - Ingresos: $688900.00
#   Cubo mágico 8x8 - Ingresos: $696900.00
#
# Tienda 2 - TOP 3 productos que MÁS dinero generaron:
#   Iphone 15 - Ingresos: $113225800.00
#   TV LED UHD 4K - Ingresos: $103375000.00
#   Refrigerador - Ingresos: $97632500.00
#
# Tienda 2 - TOP 3 productos que MENOS dinero generaron:
#   Cubo mágico 8x8 - Ingresos: $643600.00
#   Dinosaurio Rex - Ingresos: $770300.00
#   Cuerda para saltar - Ingresos: $856900.00
#
# Tienda 3 - TOP 3 productos que MÁS dinero generaron:
#   Refrigerador - Ingresos: $99889700.00
#   TV LED UHD 4K - Ingresos: $96669100.00
#   Iphone 15 - Ingresos: $93225700.00
#
# Tienda 3 - TOP 3 productos que MENOS dinero generaron:
#   Cubo mágico 8x8 - Ingresos: $640400.00
#   Dinosaurio Rex - Ingresos: $795600.00
#   Cuerda para saltar - Ingresos: $853800.00
#
# Tienda 4 - TOP 3 productos que MÁS dinero generaron:
#   Iphone 15 - Ingresos: $96697500.00
#   TV LED UHD 4K - Ingresos: $90295300.00
#   Smart TV - Ingresos: $82790400.00
#
# Tienda 4 - TOP 3 productos que MENOS dinero generaron:
#   Cuerda para saltar - Ingresos: $704800.00
#   Cubo mágico 8x8 - Ingresos: $748400.00
#   Dinosaurio Rex - Ingresos: $858100.00

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
def calcular_envio_promedio(datos_tienda, tienda_numero):
    costos_envio = []

    for venta in datos_tienda:
        costo_envio = float(venta['Costo de envío'])
        costos_envio.append(costo_envio)

    # La condición if costos_envio evalúa si la lista costos_envio no está vacía.
    # En Python, una lista vacía ([]) se evalúa como False, y una lista con elementos se evalúa como True.
    # Este es un if ternario (una forma compacta de escribir un if en una sola línea).
    promedio_envio = sum(costos_envio) / len(costos_envio) if costos_envio else 0

    print(f"Tienda {tienda_numero} - Envío promedio: ${promedio_envio:.2f}")

# Procesar todas las tiendas
for i, url in enumerate(urls, start=1):
    datos_tienda = leer_csv(url)
    calcular_envio_promedio(datos_tienda, i)
# Out:
# Tienda 1 - Envío promedio: $26018.61
# Tienda 2 - Envío promedio: $25216.24
# Tienda 3 - Envío promedio: $24805.68
# Tienda 4 - Envío promedio: $23459.46

# %%
# Asegurar que el costo de envío es numérico
df_total['Costo de envío'] = df_total['Costo de envío'].astype(float)

# Agrupar por tienda y calcular el promedio del costo de envío
envio_promedio = df_total.groupby('Tienda')['Costo de envío'].mean()

# Mostrar resultados
print("\nEnvío promedio por tienda:")
for tienda, promedio in envio_promedio.items():
    print(f"{tienda}: ${promedio:.2f}")
# Out:
# Envío promedio por tienda:
# Tienda 1: $26018.61
# Tienda 2: $25216.24
# Tienda 3: $24805.68
# Tienda 4: $23459.46

# %%
# %pip install matplotlib
import matplotlib.pyplot as plt
# Aquí empleamos el df concatenado del ejercicio 4
# Asegurar tipo correcto
df_total['Precio'] = df_total['Precio'].astype(float)

# El ingreso de cada venta es simplemente el precio
df_total['Ingreso'] = df_total['Precio']

# Agrupar datos
ingresos_totales = df_total.groupby('Tienda')['Ingreso'].sum()
ingreso_promedio = df_total.groupby('Tienda')['Ingreso'].mean()
distribucion_ingresos = ingresos_totales

# 🎨 Graficar 3 gráficos verdaderamente diferentes

# 1. Barra vertical: Total de ingresos
plt.figure(figsize=(8,5))
ingresos_totales.plot(kind='bar')
plt.title('Ingresos Totales por Tienda')
plt.ylabel('Total Ingresos (USD)')
plt.xlabel('Tienda')
plt.grid(axis='y')
plt.tight_layout() #plt.tight_layout() en Matplotlib se usa para ajustar automáticamente los elementos del gráfico y no se solapen entre sí
plt.show()

# 2. Línea: Promedio de ingreso por venta
plt.figure(figsize=(8,5))
ingreso_promedio.plot(kind='line', marker='o', linestyle='--', color='orange')
plt.title('Ingreso Promedio por Venta por Tienda')
plt.ylabel('Ingreso Promedio (USD)')
plt.xlabel('Tienda')
plt.grid(True)
plt.tight_layout()
plt.show()

# 3. Torta/Pie: Distribución del total
plt.figure(figsize=(7,7))
distribucion_ingresos.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Participación de Cada Tienda en el Total de Ingresos')
plt.ylabel('')
plt.tight_layout()
plt.show()
# Out:
# Requirement already satisfied: matplotlib in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jimoc\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: C:\Users\jimoc\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
